# %% [markdown]
# <a href="https://colab.research.google.com/github/fagonzalezo/qmc/blob/master/examples/qmc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False

if IN_COLAB:
    # !rm -R qmc qmc1
    # !git clone https://github.com/stoledoc/QMC_Multimodal.git
    # !mv qmc qmc1
    # !mv qmc1/qmc .
else:
    import sys
    sys.path.insert(0, "../")

# %%
# %matplotlib inline
import numpy as np
import pylab as pl

# Function to visualize a 2D dataset
def plot_data(X, y):
    y_unique = np.unique(y)
    colors = pl.cm.rainbow(np.linspace(0.0, 1.0, y_unique.size))
    for this_y, color in zip(y_unique, colors):
        this_X = X[y == this_y]
        pl.scatter(this_X[:, 0], this_X[:, 1],  c=color,
                    alpha=0.5, edgecolor='k',
                    label="Class %s" % this_y)
    pl.legend(loc="best")
    pl.title("Data")
    
# Function to visualize the decission surface of a classifier
def plot_decision_region(X, pred_fun):
    min_x = np.min(X[:, 0])
    max_x = np.max(X[:, 0])
    min_y = np.min(X[:, 1])
    max_y = np.max(X[:, 1])
    min_x = min_x - (max_x - min_x) * 0.05
    max_x = max_x + (max_x - min_x) * 0.05
    min_y = min_y - (max_y - min_y) * 0.05
    max_y = max_y + (max_y - min_y) * 0.05
    x_vals = np.linspace(min_x, max_x, 50)
    y_vals = np.linspace(min_y, max_y, 50)
    XX, YY = np.meshgrid(x_vals, y_vals)
    grid_r, grid_c = XX.shape
    vals = [[XX[i, j], YY[i, j]] for i in range(grid_r) for j in range(grid_c)]
    preds = pred_fun(np.array(vals))
    ZZ = np.reshape(preds, (grid_r, grid_c))
    print(np.min(preds), np.min(ZZ))
    pl.contourf(XX, YY, ZZ, 100, cmap = pl.cm.coolwarm, vmin= 0, vmax=1)
    pl.colorbar()
    CS = pl.contour(XX, YY, ZZ, 100, levels = [0.1*i for i in range(1,10)])
    pl.clabel(CS, inline=1, fontsize=10)
    pl.xlabel("x")
    pl.ylabel("y")

def gen_pred_fun(clf):
    def pred_fun(X):
        return clf.predict(X)[:, 1]
    return pred_fun

# %% [markdown]
# ### Two moons example

# %%
from sklearn.metrics import accuracy_score
from sklearn.datasets import make_blobs, make_moons, make_circles
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
import tensorflow as tf
import qmc.tf.layers as layers
import qmc.tf.models as models
# Out:
# /home/santiago/anaconda3/envs/qmc/lib/python3.8/site-packages/typeguard/__init__.py:885: UserWarning: no type annotations present -- not typechecking qmc.tf.layers.CrossProduct.__init__
#   warn('no type annotations present -- not typechecking {}'.format(function_name(func)))
# /home/santiago/anaconda3/envs/qmc/lib/python3.8/site-packages/typeguard/__init__.py:885: UserWarning: no type annotations present -- not typechecking qmc.tf.layers.DensityMatrix2Dist.__init__
#   warn('no type annotations present -- not typechecking {}'.format(function_name(func)))
# /home/santiago/anaconda3/envs/qmc/lib/python3.8/site-packages/typeguard/__init__.py:885: UserWarning: no type annotations present -- not typechecking qmc.tf.layers.DensityMatrixRegression.__init__
#   warn('no type annotations present -- not typechecking {}'.format(function_name(func)))

# %%
X, y = make_moons(n_samples=2000, noise=0.2, random_state=0)
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.33, random_state=42)
y_train = y_train[:, np.newaxis]
y_test = y_test[:, np.newaxis]

# %%
fm_x = layers.QFeatureMapRFF(2, dim=150, gamma=20, random_state=17)
fm_y = layers.QFeatureMapOneHot(num_classes=2)
qmc = models.QMClassifier(fm_x, fm_y, dim_x=150, dim_y=2)
qmc.compile()
qmc.fit(X_train, y_train, epochs=1)
out = qmc.predict(X_test)
print(out[:10])
# Out:
# 42/42 [==============================] - 0s 7ms/step
# [[0.13299659 0.86700326]
#  [0.7116439  0.28835574]
#  [0.10563791 0.89436233]
#  [0.13841362 0.861586  ]
#  [0.43258366 0.5674165 ]
#  [0.92546415 0.07453603]
#  [0.41180333 0.5881964 ]
#  [0.1396376  0.8603624 ]
#  [0.8561922  0.14380799]
#  [0.16786237 0.8321373 ]]

# %%
print(accuracy_score(y_test, out[:,1] >= 0.5))
pl.figure(figsize = (8,16/3))    
plot_decision_region(X_test, gen_pred_fun(qmc))
plot_data(X, y)
# Out:
# 0.9333333333333333
# 0.018187225 0.018187225
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
qmc.summary()
# Out:
# Model: "qm_classifier"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# q_feature_map_rff (QFeatureM multiple                  450
# _________________________________________________________________
# q_feature_map_one_hot (QFeat multiple                  0
# _________________________________________________________________
# q_measure_classif (QMeasureC multiple                  90000
# _________________________________________________________________
# density_matrix2dist (Density multiple                  0
# _________________________________________________________________
# cross_product (CrossProduct) multiple                  0
# _________________________________________________________________
# cross_product_1 (CrossProduc multiple                  0
# =================================================================
# Total params: 90,451
# Trainable params: 90,450
# Non-trainable params: 1
# _________________________________________________________________

# %%
fm_x = layers.QFeatureMapRFF(input_dim=2, dim=150, gamma=20, random_state=17)
x_in_dim = 2
x_out_dim = fm_x.compute_output_shape((1, x_in_dim))[1]
fm_y = layers.QFeatureMapOneHot(num_classes=2)


qmc = models.QMFindingsClassifier(fm_x=fm_x, fm_y_1=fm_y, fm_y_2=fm_y, fm_y=fm_y, dim_x=x_out_dim, dim_y_1=2, dim_y_2=2, dim_y=2)
qmc.compile()

qmc.fit(X_train, (y_train, y_train, y_train), epochs = 1, batch_size = 32)
out = qmc.predict(X_test)

print('prediccion', out[:10])

print(accuracy_score(y_test, out[:,1] >= 0.5))
# Out:
# 42/42 [==============================] - 8s 189ms/step
# prediccion [[0.03285732 0.9671427 ]
#  [0.9384262  0.06157387]
#  [0.03188039 0.9681196 ]
#  [0.03311451 0.9668855 ]
#  [0.28364807 0.716352  ]
#  [0.97174287 0.02825714]
#  [0.22976206 0.7702379 ]
#  [0.0331761  0.9668239 ]
#  [0.96969754 0.03030243]
#  [0.03502936 0.96497065]]
# 0.9333333333333333

# %%
pl.figure(figsize = (8,16/3))
plot_decision_region(X_test, gen_pred_fun(qmc))
plot_data(X, y)
# Out:
# 0.027836118 0.027836118
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
qmc.summary()
# Out:
# Model: "qm_findings_classifier"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# q_feature_map_rff_1 (QFeatur multiple                  450
# _________________________________________________________________
# q_feature_map_one_hot_1 (QFe multiple                  0
# _________________________________________________________________
# q_measure_classif_1 (QMeasur multiple                  90000
# _________________________________________________________________
# q_measure_classif_2 (QMeasur multiple                  90000
# _________________________________________________________________
# q_measure_classif_3 (QMeasur multiple                  64
# _________________________________________________________________
# density_matrix2dist_1 (Densi multiple                  0
# _________________________________________________________________
# density_matrix2dist_2 (Densi multiple                  0
# _________________________________________________________________
# cross_product_2 (CrossProduc multiple                  0
# _________________________________________________________________
# cross_product_3 (CrossProduc multiple                  0
# _________________________________________________________________
# cross_product_4 (CrossProduc multiple                  0
# _________________________________________________________________
# cross_product_5 (CrossProduc multiple                  0
# _________________________________________________________________
# cross_product_6 (CrossProduc multiple                  0
# _________________________________________________________________
# cross_product_7 (CrossProduc multiple                  0
# _________________________________________________________________
# cross_product_8 (CrossProduc multiple                  0
# =================================================================
# Total params: 180,515
# Trainable params: 180,514
# Non-trainable params: 1
# _________________________________________________________________

# %%
rhos = qmc.get_rho()

# %%
len(rhos)
# Out:
# 3

# %%
rhos[0].shape
# Out:
# TensorShape([150, 2, 150, 2])

# %%
rhos[1].shape
# Out:
# TensorShape([150, 2, 150, 2])

# %%
rhos[2].shape
# Out:
# TensorShape([4, 2, 4, 2])

# %%
rho_1, rho_2, rho = qmc.get_rho()

# %%
qmc1 = models.QMFindingsClassifierSGD(input_dim=2, dim_x=150, dim_y_1=2, dim_y_2=2, dim_y=2, gamma=20, random_state=17)

#eig_vals = qmc1.set_rho(qmc.get_rho())
qmc1.set_rho_1(rho_1)
qmc1.set_rho_2(rho_2)
qmc1.set_rho(rho)

out = qmc1.predict(X_test)
print(accuracy_score(y_test, out[:,1] >= 0.5))
pl.figure(figsize = (8,16/3))    
plot_decision_region(X_test, gen_pred_fun(qmc1))
plot_data(X, y)
# Out:
# 0.9333333333333333
# 0.02783611 0.02783611
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.005)
qmc1 = models.QMFindingsClassifierSGD(input_dim=2, dim_x=150, dim_y_1=2, dim_y_2=2, dim_y=2, num_eig=5, gamma=20, random_state=17)
qmc1.compile(optimizer, loss=tf.keras.losses.CategoricalCrossentropy())
#qmc1.set_rho(qmc.get_rho())
qmc1.set_rho_1(rho_1)
qmc1.set_rho_2(rho_2)
qmc1.set_rho(rho)
y_train_bin = tf.reshape (tf.keras.backend.one_hot(y_train, 2), (-1,2))
qmc1.fit(X_train, y_train_bin, epochs=1)
# Out:
# 42/42 [==============================] - 34s 818ms/step - loss: 0.0886

# %%
out = qmc1.predict(X_test)
print(accuracy_score(y_test, out[:,1] >= 0.5))
pl.figure(figsize = (8,16/3))
plot_decision_region(X_test, gen_pred_fun(qmc1))
plot_data(X, y)
# Out:
# 0.9651515151515152
# 0.00014335828 0.00014335828
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
